# %% [markdown]
# ### Comparing observations and simulations at stations, NetCDF4
#
# Given a list of stations in *observation_locations.xlsx* and a folder **Observations** with an Excel file for each station, we compare observations and simulations using any number of simulation runs. Figures are interactive with Plotly, and statistics are calculated.
#
# - The folder we point to contains *observation_locations.xlsx* and a folder **Observations**
# - *observations_locations.xlsx* has three columns: Station name, Latitude, Longitude
# - **Observations** holds Excel files named after the station names, ex., StationName.xlsx
# - Each StationName.xlsx Excel has two columns: Date, Observation
#
# - Each folder in user-input array **Simulation_output_folders** holds the NetCDF4 output *output_netcdf.nc* with the variable *output_varaible*.
#
# #### Player's guide:
# ✔️ update the following variables/paths in the next box:
# - output netcdf (this is the name of the CWatM output file before .nc)
# - variable name
# - Simulation output folders (each containing the output output_netcdf.nc)
# - titles (for the different simulations)
# - observations folder (contains *observation_locations.xlsx* and a folder **Observations**)<br>
#
# 🧰 Requires packages: notebook, pandas, plotly, netcdf4, xlrd, openpyxl <br>
# ⏩ Run with the black and white fast-forward icon above.

# %%
# Used only if Netcdf outputs are used: "filename".nc
output_netcdf = 'lakeResStorage_daily'
# NetCDF output variable, but also used for the figure titles
output_variable = 'lakeResStorage'

# NetCDF Simulation folders, all holding the NetCDF4 output_netcdf.nc with the variable output_variable
Simulation_output_folders = [
    r"C:\Users\Smilovic\OneDrive - ETH Zurich\Dokumente\Patterns_in_Reservoir_Management\ThreeGorgesDam\Standard CWatM",
    r"C:\Users\Smilovic\OneDrive - ETH Zurich\Dokumente\Patterns_in_Reservoir_Management\ThreeGorgesDam\Empirical mean",
    r"C:\Users\Smilovic\OneDrive - ETH Zurich\Dokumente\Patterns_in_Reservoir_Management\ThreeGorgesDam\Empirical median",
    #r"C:\Users\Smilovic\OneDrive - ETH Zurich\Dokumente\Patterns_in_Reservoir_Management\ThreeGorgesDams\Hold-Steady"
]

# Excel Simulation folders
Simulated_stations_Excel_folders = []

# Titles for the different simulations 
titles = [
    'observations', 
    'Standard CWatM',
    "Empirical mean",
    "Empirical median",
    #"Hold-Steady",
         ]

#colours_lines = ['#36e8f3', '#ff00ff']
#colours_lines = ['#76f4ff', '#ff00ff']
write_excel_obs_sims = True
# There is a folder called Observations inside of this folder, and a file called observations_locations.xlsx
observations_folder = r"C:\Users\Smilovic\OneDrive - ETH Zurich\Dokumente\Patterns_in_Reservoir_Management\ThreeGorgesDam"

# OBSERVATIONS FOLDER STRUCTURE
# observations_folder
# ↵ observations_locations.xlsx
# ↵ Observations
#   ↵ StationName1.xlsx #two columns: Date, Observation
#   ↵ StationName2.xlsx #two columns: Date, Observation
#   ↵ ...

# %% [markdown]
# -----------------

# %%
run functions/_functions_Compare_sims_and_obs_at_stations.ipynb
# Out:
# Loading observations
# Loading simulations
# No spatial information
# No spatial information
# No spatial information
# i 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_39692\1910603425.py:21
#      17         Excel_timeseries_observations.to_excel(writer, sheet_name='Observations', index=False)
#      19 RMSD, NRMSD, KGE, bias, corr, NS = [],[],[],[],[],[]
# ---> 21 Excel_timeseries_simulations = pd.DataFrame({'Simulated dates':DATES_SIMULATED[0][i]})
#      23 for sim in range(len(Simulated_output_paths)+len(Simulated_stations_Excel_folders)):
#      24     print('sim', sim)
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('run', 'functions/_functions_Compare_sims_and_obs_at_stations.ipynb')
#
# File ~\Envs\cwatm\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\Envs\cwatm\Lib\site-packages\IPython\core\magics\execution.py:741, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     739     with preserve_keys(self.shell.user_ns, '__file__'):
#     740         self.shell.user_ns['__file__'] = filename
# --> 741         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     742     return
#     744 # Control the response to exit() calls made by the script being run
#
# File ~\Envs\cwatm\Lib\site-packages\IPython\core\interactiveshell.py:3005, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    3003 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    3004 if raise_exceptions:
# -> 3005     result.raise_error()
#    3006 elif not result.success:
#    3007     break
#
# File ~\Envs\cwatm\Lib\site-packages\IPython\core\interactiveshell.py:308, in ExecutionResult.raise_error(self)
#     306     raise self.error_before_exec
#     307 if self.error_in_exec is not None:
# --> 308     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_39692\1910603425.py:21
#      17         Excel_timeseries_observations.to_excel(writer, sheet_name='Observations', index=False)
#      19 RMSD, NRMSD, KGE, bias, corr, NS = [],[],[],[],[],[]
# ---> 21 Excel_timeseries_simulations = pd.DataFrame({'Simulated dates':DATES_SIMULATED[0][i]})
#      23 for sim in range(len(Simulated_output_paths)+len(Simulated_stations_Excel_folders)):
#      24     print('sim', sim)
#
# IndexError: list index out of range
